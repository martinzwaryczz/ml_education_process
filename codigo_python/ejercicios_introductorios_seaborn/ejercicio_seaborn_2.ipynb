# %%
# Con el mismo set de datos realizar el mismo gráfico con un lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

pinguinos = sns.load_dataset("penguins")
pinguinos.columns = ["especie", "isla", "longitud_pico", "profundidad_pico", "longitud_aleta", "masa", "sexo"]

# %%
sns.relplot(data=pinguinos,
            x="especie",
            y="masa",
            kind="line", # Acá asignamos que sean lineas y no puntos
            hue="sexo",
            style="sexo")

plt.show()
# Out:
# c:\Users\marti\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Mismo tipo de grafico, diferentes parametros

sns.relplot(data=pinguinos,
            x="profundidad_pico",
            y="longitud_aleta",
            kind="line",
            hue="especie",
            style="especie")

plt.show()

# %%
# Scatterplot
sns.relplot(data=pinguinos,
            x="profundidad_pico",
            y="longitud_aleta",
            kind="scatter",
            hue="especie",
            style="especie")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Scatterplot
# ----> 2 sns.relplot(data=pinguinos,
#       3             x="profundidad_pico",
#       4             y="longitud_aleta",
#       5             kind="scatter",
#       6             hue="especie",
#       7             style="especie")
#       9 plt.show()
#
# NameError: name 'sns' is not defined
