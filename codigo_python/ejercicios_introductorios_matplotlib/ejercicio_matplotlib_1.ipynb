# %%
# Gráficar sen(x), cos(x) y sen(x)^2+cos(x)^2
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 2 * np.pi, 200)
y= np.cos(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 2 * np.pi, 200)
y = (np.cos(x) ** 2) + (np.sin(x) **2)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()
